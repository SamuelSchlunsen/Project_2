# %%
# Import Dependancies
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Read in CSV
covid_df = pd.read_csv("../Resources.kd/covid-19-cases.csv")
covid_df
# Out:
#         Case_Type  Cases  Difference       Date Country_Region Province_State  \
# 0       Confirmed    319           1  4/11/2020      Mauritius            NaN
# 1          Deaths      0           0  2/27/2020        Bahamas            NaN
# 2       Confirmed     16           0  2/16/2020        Germany            NaN
# 3          Deaths      0           0  1/31/2020         Canada        Alberta
# 4          Deaths      0           0   3/4/2020      Australia     Queensland
# ...           ...    ...         ...        ...            ...            ...
# 582655     Deaths      0           0  1/22/2020             US    Mississippi
# 582656  Confirmed      0           0  1/22/2020             US        Alabama
# 582657  Confirmed      0           0  1/22/2020             US      Tennessee
# 582658     Deaths      0           0  1/22/2020             US      Louisiana
# 582659     Deaths      0           0  1/22/2020             US     New Jersey
#
# ...

# %%
covid_df.info
# Out:
# <bound method DataFrame.info of         Case_Type  Cases  Difference       Date Country_Region Province_State  \
# 0       Confirmed    319           1  4/11/2020      Mauritius            NaN
# 1          Deaths      0           0  2/27/2020        Bahamas            NaN
# 2       Confirmed     16           0  2/16/2020        Germany            NaN
# 3          Deaths      0           0  1/31/2020         Canada        Alberta
# 4          Deaths      0           0   3/4/2020      Australia     Queensland
# ...           ...    ...         ...        ...            ...            ...
# 582655     Deaths      0           0  1/22/2020             US    Mississippi
# 582656  Confirmed      0           0  1/22/2020             US        Alabama
# 582657  Confirmed      0           0  1/22/2020             US      Tennessee
# 582658     Deaths      0           0  1/22/2020             US      Louisiana
# 582659     Deaths      0           0  1/22/2020             US     New Jersey
#
# ...

# %%
covid_df["Date"] = pd.to_datetime(covid_df.Date)
covid_df.head()
# Out:
#    Case_Type  Cases  Difference       Date Country_Region Province_State  \
# 0  Confirmed    319           1 2020-04-11      Mauritius            NaN
# 1     Deaths      0           0 2020-02-27        Bahamas            NaN
# 2  Confirmed     16           0 2020-02-16        Germany            NaN
# 3     Deaths      0           0 2020-01-31         Canada        Alberta
# 4     Deaths      0           0 2020-03-04      Australia     Queensland
#
#   Admin2 Combined_Key  FIPS      Lat      Long  Table_Names Prep_Flow_Runtime
# 0    NaN          NaN   NaN -20.2000   57.5000  Time Series   4/13/2020 21:18
# 1    NaN          NaN   NaN  25.0343  -77.3963  Time Series   4/13/2020 21:18
# 2    NaN          NaN   NaN  51.0000    9.0000  Time Series   4/13/2020 21:18
# 3    NaN          NaN   NaN  53.9333 -116.5765  Time Series   4/13/2020 21:18
# 4    NaN          NaN   NaN -28.0167  153.4000  Time Series   4/13/2020 21:18

# %%
cases = covid_df['Cases'].sum()
cases
# Out:
# 30731425
